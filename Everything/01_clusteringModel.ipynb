# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import shapely.ops as so
import matplotlib.patches as mpatches
import joblib
import dataframe_image as dfi

from IPython.core.interactiveshell import InteractiveShell 
InteractiveShell.ast_node_interactivity = "all"
import warnings
warnings.filterwarnings('ignore')

streetview = pd.read_csv('../MorrisCountyImages/csv/morris_pred_grouped.csv')
census = pd.read_csv('../CensusScrap/censusMorrisCleaned.csv')
bps = pd.read_csv('../BPS/morrisCountyBPS.csv')
greenSpace = pd.read_csv('../GreenSpace/green_space_estimates.csv')

towns_shapefile = "../MorrisCountyImages/Municipalities/Municipalities.shp"
townSize = gpd.read_file(towns_shapefile).reset_index()
townSize = townSize.to_crs(4326)[["Label","GISAcres"]].sort_values(by="Label", ascending=True)
townSize.GISAcres = np.int64(townSize.GISAcres)

# %% [markdown]
# ## 1.) Merge datasets

# %%
combined = pd.merge(census, bps, on='town', how='inner').merge(streetview, on='town', how='inner')
for col in combined.columns[1:]:
    if combined[col].dtype == object:
        combined[col] = [np.int64(x.replace(',','').replace('-','0').replace('+','')) for x in combined[col]] 
        ### Convert string with commas to int64
combined = pd.merge(combined, townSize, left_on='town', right_on='Label', how='inner').drop('Label',axis=1)
combined = pd.merge(combined, greenSpace, on='town', how='left') # greenSpace doesn't have all towns
combined.fillna(0, inplace=True)

# %% [markdown]
# #### Combing columns to standardize values to remove town size as a factor, and drop unhelpful features

# %%
combined["OccupiedHousingUnits"] = combined["Occupied housing units"]/combined["TOTAL_UNITS"]
combined["OwnerOccupied"] = combined["Owner-occupied"]/combined["TOTAL_UNITS"]
combined["RenterOccupied"] = combined["Renter-occupied"]/combined["TOTAL_UNITS"]
combined["BuiltRecently"] = combined[['Built 2020 or later', 'Built 2010 to 2019', 'Built 2000 to 2009',
       'Built 1990 to 1999', 'Built 1980 to 1989', 'Built 1970 to 1979',
       'Built 1960 to 1969', 'Built 1950 to 1959', 'Built 1940 to 1949',
       'Built 1939 or earlier']].T.sum()/combined["TOTAL_UNITS"]
combined["AvgUnitValue"] = combined["TOTAL_VALUE"]//combined["TOTAL_UNITS"]
combined["ParkSpace"] = combined["Park_Size_Acres"]/combined["GISAcres"]

combined.drop(['Occupied housing units', 'Owner-occupied', 'Renter-occupied',
       'Built 2020 or later', 'Built 2010 to 2019', 'Built 2000 to 2009',
       'Built 1990 to 1999', 'Built 1980 to 1989', 'Built 1970 to 1979',
       'Built 1960 to 1969', 'Built 1950 to 1959', 'Built 1940 to 1949',
       'Built 1939 or earlier', 'TOTAL_UNITS', 'TOTAL_VALUE', 'UNITS_1_UNIT',
       'UNITS_2_UNITS', 'UNITS_3_4_UNITS', 'UNITS_5_UNITS', 'VALUE_1_UNIT',
       'VALUE_2_UNITS', 'VALUE_3_4_UNITS', 'VALUE_5_UNITS','GISAcres','Park_Size_Acres'],axis=1,inplace=True)

# %%
combined
# Out:
#                               town  Median Home Value  Median Gross Rent  \
# 0                     Boonton Town             468900               1637
# 1                 Boonton Township             683600               2155
# 2                   Butler Borough             396700               1466
# 3                  Chatham Borough             944600               2201
# 4                 Chatham Township            1025300               2359
# 5                  Chester Borough             614700               1508
# 6                 Chester Township             776100                  0
# 7                Denville Township             512700               1769
# 8                       Dover Town             316900               1698
# 9            East Hanover Township             669000               3033
# 10            Florham Park Borough             705200               2891
# 11                Hanover Township             611600               2794
# 12                Harding Township            1262400               1498
# 13              Jefferson Township             381500               1483
# 14                Kinnelon Borough             681800               2288
# 15            Lincoln Park Borough             407700               1655
# 16              Long Hill Township             656400               1880
# 17                 Madison Borough             844700               2168
# 18                 Mendham Borough             759800               3049
# 19                Mendham Township            1054100               1488
# 20              Mine Hill Township             363600               1807
# 21              Montville Township             651200               2243
# 22                 Morris Township             692800               2243
# 23           Morris Plains Borough             602000               2636
# 24                 Morristown Town             535900               2147
# 25          Mountain Lakes Borough             869800               3500
# 26         Mount Arlington Borough             374300               2230
# 27            Mount Olive Township             434200               1584
# 28                 Netcong Borough             332600               1378
# 29  Parsippany-Troy Hills Township             502000               1629
# 30             Pequannock Township             487800               3170
# 31               Randolph Township             621600               1741
# 32               Riverdale Borough             383000               2568
# 33                Rockaway Borough             395500               1548
# 34               Rockaway Township             423100               2072
# 35                Roxbury Township             420400               1832
# 36         Victory Gardens Borough             224500               1386
# 37             Washington Township             535500               1862
# 38                 Wharton Borough             324600               1815
#
#     pred  SUM_BLACK_SVC  SUM_WHITE_SVC  SUM_HISP_SVC  SUM_HHILOWSVCA  \
# 0      2       0.051274       0.629349      0.156048        0.104875
# 1      0       0.000000       0.000000      0.000000        0.000000
# 2      4       0.015903       0.696456      0.215385        0.117027
# 3      2       0.009262       0.777167      0.069036        0.036403
# 4      0       0.018290       0.776124      0.069616        0.035588
# 5      2       0.002604       0.751736      0.171007        0.088542
# 6      3       0.004405       0.770925      0.140969        0.061674
# 7      2       0.000000       0.000000      0.000000        0.000000
# 8      1       0.040533       0.193569      0.715091        0.101973
# 9      2       0.000000       0.000000      0.000000        0.000000
# 10     1       0.014419       0.825901      0.051535        0.060080
# 11     4       0.000000       0.804878      0.048780        0.121951
# 12     3       0.000000       0.000000      0.000000        0.000000
# 13     7       0.023026       0.736842      0.157895        0.082237
# 14     1       0.011211       0.800245      0.086629        0.046881
# 15     0       0.014405       0.753414      0.136470        0.058685
# 16     4       0.000000       0.000000      0.000000        0.000000
# 17     4       0.025934       0.701346      0.152901        0.072705
# 18     0       0.006911       0.859628      0.059104        0.045758
# 19     0       0.000000       0.000000      0.000000        0.000000
# 20     0       0.000000       0.000000      0.000000        0.000000
# 21     4       0.000000       0.000000      0.000000        0.000000
# 22     1       0.000000       0.000000      0.000000        0.000000
# 23     4       0.031912       0.738877      0.124610        0.048122
# 24     1       0.092926       0.441639      0.381165        0.095241
# 25     2       0.013243       0.721048      0.070442        0.052550
# 26     6       0.027307       0.728213      0.148733        0.082849
# 27     2       0.039330       0.672836      0.146570        0.065732
# 28     2       0.035997       0.639265      0.239980        0.125862
# 29     5       0.013957       0.654950      0.081416        0.033600
# 30     3       0.012500       0.947500      0.010000        0.272500
# 31     1       0.000000       0.000000      0.000000        0.000000
# 32     0       0.024590       0.771237      0.136364        0.069300
# 33     0       0.028205       0.655941      0.199674        0.068527
# 34     0       0.024029       0.696916      0.182379        0.061113
# 35     2       0.023911       0.749502      0.140194        0.062340
# 36     2       0.000000       0.000000      0.000000        0.000000
# 37     0       0.006818       0.847727      0.077273        0.027273
# 38     0       0.033671       0.365998      0.514694        0.092740
#
#     SUM_HHIMEDSVCA  SUM_HHIHIGHSVCA  OccupiedHousingUnits  OwnerOccupied  \
# 0         0.084345         0.191242              0.580514       0.326475
# 1         0.000000         0.000000              0.262073       0.234955
# 2         0.132757         0.168712              0.643266       0.438204
# 3         0.038449         0.261066              0.416314       0.349421
# 4         0.053311         0.263434              0.361714       0.303449
# 5         0.064236         0.220486              0.090527       0.067196
# 6         0.061674         0.242291              0.324193       0.312970
# 7         0.000000         0.000000              0.414784       0.349516
# 8         0.091981         0.122137              0.713222       0.316457
# 9         0.000000         0.000000              0.334589       0.314812
# 10        0.058478         0.249933              0.203340       0.141305
# 11        0.097561         0.195122              0.279313       0.227132
# 12        0.000000         0.000000              0.551487       0.438724
# 13        0.075658         0.213816              0.470076       0.424768
# 14        0.071341         0.250917              0.560074       0.516064
# 15        0.106167         0.200918              1.233373       0.955362
# 16        0.000000         0.000000              1.930826       1.713230
# 17        0.062058         0.229827              0.583959       0.371341
# 18        0.054814         0.260486              0.217756       0.182820
# 19        0.000000         0.000000              0.426863       0.412382
# 20        0.000000         0.000000              0.592781       0.538854
# 21        0.000000         0.000000              0.238827       0.211542
# 22        0.000000         0.000000              0.441469       0.378956
# 23        0.082820         0.267623              0.174403       0.129697
# 24        0.098914         0.223073              0.376198       0.139188
# 25        0.045928         0.235841              0.389328       0.374626
# 26        0.108297         0.226935              0.135338       0.092311
# 27        0.099075         0.181002              0.426047       0.264377
# 28        0.121011         0.149860              1.862550       0.974104
# 29        0.066684         0.233135              0.987874       0.590522
# 30        0.167500         0.265000              0.361194       0.301634
# 31        0.000000         0.000000              0.394887       0.297318
# 32        0.065574         0.283159              0.108330       0.075899
# 33        0.103961         0.206802              1.905483       1.163059
# 34        0.077213         0.224429              0.238900       0.196298
# 35        0.081697         0.212923              0.371857       0.318650
# 36        0.000000         0.000000              1.810811       0.629730
# 37        0.043939         0.264394              0.515166       0.459205
# 38        0.132445         0.122616              0.187846       0.103285
#
#     RenterOccupied  BuiltRecently  AvgUnitValue  ParkSpace
# 0         0.254038       0.618772        112566   0.058152
# 1         0.027117       0.284547        247909   0.000000
# 2         0.205062       0.650841         87567   0.002840
# 3         0.066892       0.431555        234294   0.021895
# 4         0.058265       0.370172        283555   0.102636
# 5         0.023332       0.092705        116210   0.014161
# 6         0.011223       0.341793        231164   0.003851
# 7         0.065268       0.449968        137177   0.000000
# 8         0.396764       0.742435         91248   0.259522
# 9         0.019777       0.343750        119778   0.000000
# 10        0.062034       0.214472        129618   0.014171
# 11        0.052181       0.286496        107790   0.022174
# 12        0.112763       0.579405        693682   0.000000
# 13        0.045309       0.506627        100161   0.109406
# 14        0.044009       0.574967        272226   0.147436
# 15        0.278011       1.271720         99469   0.020807
# 16        0.217596       1.969778        244824   0.000000
# 17        0.212618       0.608052        214452   0.063466
# 18        0.034936       0.224894         93097   0.065950
# 19        0.014481       0.439664        286173   0.000000
# 20        0.053928       0.621231         93450   0.000000
# 21        0.027284       0.244254        139358   0.000000
# 22        0.062513       0.451216        154363   0.000000
# 23        0.044706       0.183601        132046   0.063900
# 24        0.237010       0.391248        144235   0.091168
# 25        0.014702       0.404574        224251   0.465096
# 26        0.043026       0.161153         76031   1.052577
# 27        0.161670       0.439963        131806   0.049677
# 28        0.888446       1.986056        304849   0.049691
# 29        0.397352       1.014043        106981   0.025537
# 30        0.059559       0.374687         88204   0.065772
# 31        0.097568       0.402690        129201   0.000000
# 32        0.032431       0.111174         50583   0.004652
# 33        0.742424       1.929293         85437   0.041381
# 34        0.042602       0.258271         72487   0.151726
# 35        0.053207       0.391445         83337   0.026084
# 36        1.181081       1.902703         58022   0.000000
# 37        0.055961       0.532928        167898   0.005552
# 38        0.084561       0.196904         40662   0.032169

# %% [markdown]
# ## 2.) Create an unsupervised clustering model
# #### Using random weight factor after standardizing to influence the feature weights by scaling the values among each other

# %%
random_weight = np.random.uniform(low=0.25, high=1.0, size=(15,))

X = combined.copy().drop(['town'],axis=1)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled_df = pd.DataFrame(X_scaled)

new_X_scaled = pd.DataFrame()
for i in range(X_scaled_df.shape[1]):
    new_X_scaled[i] = X_scaled_df[i]*random_weight[i]

# %%
random_weight
# Out:
# array([0.59208689, 0.96458258, 0.84435617, 0.65421567, 0.48946075,
#        0.2944736 , 0.49866217, 0.4490246 , 0.91653138, 0.82369686,
#        0.40860639, 0.63348241, 0.86123992, 0.35592105, 0.40986996])

# %%
#KMeans
km = KMeans(n_clusters=2, random_state=43)
km.fit(new_X_scaled)
km.predict(new_X_scaled)
km_labels = km.labels_;

# %%
result = combined.copy()
result['labels'] = km_labels

# %% [markdown]
# ## 3.) Interpreting clustering results

# %%
result0 = result[result.labels == 0]
result1 = result[result.labels == 1]
numOfTowns = pd.DataFrame(np.array([["Result0",result0.town.nunique()],["Result1",result1.town.nunique()]]))
numOfTowns
# Out:
#          0   1
# 0  Result0  22
# 1  Result1  17

# %%
table = pd.DataFrame(index=['result0','result1'])

for col in combined.columns[1:]:
    if (combined[col].dtype == float and col != "Park_Size_Acres"):
        # floats - mean
        new_col = [result0[col].mean(),result1[col].mean()]
    elif col in ["Median Home Value","Median Gross Rent"]:
        # int - median
        new_col = [np.int64(result0[col].median()),np.int64(result1[col].median())]
    else:
        new_col = [result0[col].sum(),result1[col].sum()]
    table[col] = new_col
table
# Out:
#          Median Home Value  Median Gross Rent  pred  SUM_BLACK_SVC  \
# result0             535700               2184    47       0.023140
# result1             621600               1698    30       0.008088
#
#          SUM_WHITE_SVC  SUM_HISP_SVC  SUM_HHILOWSVCA  SUM_HHIMEDSVCA  \
# result0       0.729144      0.144107        0.079173        0.081655
# result1       0.215768      0.089035        0.026489        0.032440
#
#          SUM_HHIHIGHSVCA  OccupiedHousingUnits  OwnerOccupied  RenterOccupied  \
# result0          0.22782              0.349612       0.263788        0.085823
# result1          0.06795              0.848594       0.578382        0.270212
#
#          BuiltRecently  AvgUnitValue  ParkSpace
# result0       0.364795       2963076   0.119575
# result1       0.880856       3223085   0.023576

# %%
# Saving
joblib.dump(km, './clusteringModel.pkl')
dfi.export(pd.DataFrame(random_weight).style,'../Figures/tables/randomWeights.png')
dfi.export(table.style,'../Figures/tables/tableClusteringGrouped.png')
dfi.export(numOfTowns.style,'../Figures/tables/numberOfTownsCluster.png')
# Out:
# ['./clusteringModel.pkl']

# %% [markdown]
# #### We obviously need to classify the clustering labels ourselves. From the grouped town dataframe, we could easily explore the clustering of all the features. We could see from most features including streetview changes, median gross rent and AvgUnitValue that Result0 is exhibiting signs of rural gentrification.

# %% [markdown]
# ## 4.) Prediction plot

# %%
color_labels = ['lightcoral','cornflowerblue']
color_patches = [mpatches.Patch(color=color_labels[x]) for x in range(2)]
legend_labels = []
if table.pred.values[0] > table.pred.values[1]:
    legend_labels.append('Gentrifying')
    legend_labels.append('Not Gentrifying')
else:
    legend_labels.append('Not Gentrifying')
    legend_labels.append('Gentrifying')

# %%
towns_shapefile = "../MorrisCountyImages/Municipalities/Municipalities.shp"
gdf = gpd.read_file(towns_shapefile).reset_index()
gdf = gdf.to_crs(4326)


fig,ax = plt.subplots()
ax.set_aspect('equal','datalim')


for i in range(39):
    # Plot polygon by color
    town = gdf.loc[gdf.index[i]]
    result_row = result[result.town == town.Label]
    if town.geometry.geom_type == 'Polygon':
        x, y = town.geometry.exterior.xy
        ax.fill(x, y, alpha=1, fc=color_labels[result_row.labels.values[0]], ec='none')
    elif town.geometry.geom_type == 'MultiPolygon':
        new_shape = so.unary_union(town.geometry)
        for geom in new_shape.geoms:
            x, y = geom.exterior.xy
            ax.fill(x, y, alpha=1, fc=color_labels[result_row.labels.values[0]], ec='none')
    
plt.legend(handles=color_patches, labels=legend_labels, loc='upper left')
plt.ylabel("Latitude")
plt.xlabel("Longitude")
plt.title("Predicted Towns Actively Gentrifying in Morris County")
plt.savefig("../Figures/plots/predictedTownsMorris.png", bbox_inches='tight');
plt.show();
